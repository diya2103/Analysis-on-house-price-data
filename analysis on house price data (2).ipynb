# %% [markdown]
# # Anasis On House Price Data

# %%
# import numpy
import numpy as np

# import pandas
import pandas as pd

# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# %%
# import the dataset
df_house_price_data = pd.read_csv("C:\\Users\\admin\\Downloads\\House_Price.csv")

# %%
# show first five observations of the dataset
df_house_price_data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
# show last five observations of the dataset
df_house_price_data.tail()
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 501   2.76   2.06      19.0       9.67      NO       9.348      12.1792
# 502   2.46   2.14      19.0       9.08     YES       6.612      13.1648
# 503   2.29   1.98      19.0       5.64      NO       5.478      12.1912
# 504   2.40   2.31      19.0       6.48     YES       7.940      15.1760
# 505   2.64   2.42      19.0       7.88     YES      10.280      10.1520
#
#           waterbody  rainfall bus_ter     parks
# ...

# %% [markdown]
# # 1 Data Overview

# %%
# show the column(attributes) names
df_house_price_data.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'airport',
#        'n_hos_beds', 'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter',
#        'parks'],
#       dtype='object')

# %% [markdown]
# **columninfo**
#  - `price ` : price of the house.
#  - `crime_rate ` : crime rate in that area
#  - `resid_area ` : residential of that area
#  - `air_qual ` : air quality of that area
#  - `room_num ` : residential of that area
#  - `age ` : How old that house is
#  - `dist1 ` : distance of area from house for employment 1
#  - `dist2 ` : distance of area from house for employment 2
#  - `dist3 ` : distance of area from house for employment 3
#  - `dist4 ` : distance of area from house for employment 4
#  - `teachers ` : Numbers of schools near residence
#  - `poor_prop ` : Poor population rate near the residental area
#  - `airport ` : any airport near the residence
#  - `n_hos_beds ` : hospital beds numbers
#  - `n_hot_rooms ` : Number of hotel rooms
#  - `waterbody ` : source of water near residence
#  - `rainfall ` : reainfall rate in that area
#  - `bus_ter ` : bus terminal near the residence
#  - `parks ` : Any park near the residence

# %% [markdown]
# ## Basic Statistics (Descriptive Statistics)

# %%
# shape of the data
# basic info
# basic description

# %%
# shape of the data 
df_house_price_data.shape
# Out:
# (506, 19)

# %% [markdown]
# **interpretation**
#  - we have 506 observations and 19 attributes

# %%
# basic info
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    351 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %% [markdown]
# **interpretation**
#  - we have 16 numerical attributes it includes 15 floats and 1 integer in nature
#  - we have 3 categorical attributes
#  - in the data we have valid null values

# %%
# basic description
df_house_price_data.describe().T
# Out:
#              count       mean        std        min        25%        50%  \
# price        506.0  22.528854   9.182176   5.000000  17.025000  21.200000
# crime_rate   506.0   3.613524   8.601545   0.006320   0.082045   0.256510
# resid_area   506.0  41.136779   6.860353  30.460000  35.190000  39.690000
# air_qual     506.0   0.554695   0.115878   0.385000   0.449000   0.538000
# room_num     506.0   6.284634   0.702617   3.561000   5.885500   6.208500
# age          506.0  68.574901  28.148861   2.900000  45.025000  77.500000
# dist1        506.0   3.971996   2.108532   1.130000   2.270000   3.385000
# dist2        506.0   3.628775   2.108580   0.920000   1.940000   3.010000
# dist3        506.0   3.960672   2.119797   1.150000   2.232500   3.375000
# dist4        506.0   3.618972   2.099203   0.730000   1.940000   3.070000
# teachers     506.0  21.544466   2.164946  18.000000  19.800000  20.950000
# poor_prop    506.0  12.653063   7.141062   1.730000   6.950000  11.360000
# ...

# %% [markdown]
# **interpretation**
#  - we have outliers is 'crime_rate','age','resid_area'

# %% [markdown]
# # 2 Data Preprocessing

# %%
# Data Cleaning
# Null value handling
# Outlier treatment

# %% [markdown]
# ### Data Cleaning

# %%
df_house_price_data.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'airport',
#        'n_hos_beds', 'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter',
#        'parks'],
#       dtype='object')

# %%
# let's rename the columns
df_house_price_data = df_house_price_data.rename(columns={'price':'Price' , 'crime_rate':'Crime_rate','resid_area':'Resid_area', 'air_qual' : 'Air_qual','room_num':'Air_qual','room_num': 'Room_num','age':'Age','dist1':'Dist1','dist2':'Dist2','dist3':'Dist3','dist4':'Dist4','teachers':'Teachers','poor_prop':'Poor_prop', 'airport':'Airport',
       'n_hos_beds':'N_hos_beds', 'n_hot_rooms': 'N_hot_rooms', 'waterbody' :'Waterbody', 'rainfall':'Rainfall', 'bus_ter':'Bus_ter',
       'parks':'Parks'})

# %%
df_house_price_data.head()
# Out:
#    Price  Crime_rate  Resid_area  Air_qual  Room_num   Age  Dist1  Dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    Dist3  Dist4  Teachers  Poor_prop Airport  N_hos_beds  N_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   Waterbody  Rainfall Bus_ter     Parks
# 0     River        23     YES  0.049347
# ...

# %%
# Let's do the type casting here
# Room_num
# Age
# Teachers
# N_hos_beds
# N_hot_rooms

# %%
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Price        506 non-null    float64
#  1   Crime_rate   506 non-null    float64
#  2   Resid_area   506 non-null    float64
#  3   Air_qual     506 non-null    float64
#  4   Room_num     506 non-null    float64
#  5   Age          506 non-null    float64
#  6   Dist1        506 non-null    float64
#  7   Dist2        506 non-null    float64
#  8   Dist3        506 non-null    float64
#  9   Dist4        506 non-null    float64
#  10  Teachers     506 non-null    float64
#  11  Poor_prop    506 non-null    float64
#  12  Airport      506 non-null    object
#  13  N_hos_beds   498 non-null    float64
#  14  N_hot_rooms  506 non-null    float64
#  15  Waterbody    351 non-null    object
#  16  Rainfall     506 non-null    int64
#  17  Bus_ter      506 non-null    object
# ...

# %%
df_house_price_data["Room_num"] = df_house_price_data["Room_num"].astype('int')

# %%
df_house_price_data["Age"] = df_house_price_data["Age"].astype('int')

# %%
df_house_price_data["Teachers"] = df_house_price_data["Teachers"].astype('int')

# %% [raw]
# df_house_price_data["N_hos_beds"] = df_house_price_data["N_hos_beds"].astype('int')

# %%
df_house_price_data["N_hot_rooms"] = df_house_price_data["N_hot_rooms"].astype('int')

# %%
# In previous we did typecasting based on observations and domain expertise
# now the timw is called data visulization
df_house_price_data.hist()
plt.tight_layout()
plt.show()

# %%
df_house_price_data.Price.plot(kind = 'kde')
plt.show()

# %%
# Room_num
df_house_price_data.Room_num.hist(color='purple')
plt.show()

# %%
# N_hot_rooms
df_house_price_data.N_hot_rooms.hist(color='purple')
plt.show()

# %%
# Room_num
df_house_price_data.Room_num.plot(kind = 'kde')
plt.show()

# %%
# N_hot_rooms
df_house_price_data.N_hot_rooms.plot(kind = 'kde')
plt.show()

# %%
df_house_price_data["Room_num"] = df_house_price_data["Room_num"].astype('object')

# %%
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Price        506 non-null    float64
#  1   Crime_rate   506 non-null    float64
#  2   Resid_area   506 non-null    float64
#  3   Air_qual     506 non-null    float64
#  4   Room_num     506 non-null    object
#  5   Age          506 non-null    int32
#  6   Dist1        506 non-null    float64
#  7   Dist2        506 non-null    float64
#  8   Dist3        506 non-null    float64
#  9   Dist4        506 non-null    float64
#  10  Teachers     506 non-null    int32
#  11  Poor_prop    506 non-null    float64
#  12  Airport      506 non-null    object
#  13  N_hos_beds   498 non-null    float64
#  14  N_hot_rooms  506 non-null    int32
#  15  Waterbody    351 non-null    object
#  16  Rainfall     506 non-null    int64
#  17  Bus_ter      506 non-null    object
# ...

# %% [markdown]
# ### Null value handling

# %%
df_house_price_data.head()
# Out:
#    Price  Crime_rate  Resid_area  Air_qual Room_num  Age  Dist1  Dist2  Dist3  \
# 0   24.0     0.00632       32.31     0.538        6   65   4.35   3.81   4.18
# 1   21.6     0.02731       37.07     0.469        6   78   4.99   4.70   5.12
# 2   34.7     0.02729       37.07     0.469        7   61   5.03   4.86   5.01
# 3   33.4     0.03237       32.18     0.458        6   45   6.21   5.93   6.16
# 4   36.2     0.06905       32.18     0.458        7   54   6.16   5.86   6.37
#
#    Dist4  Teachers  Poor_prop Airport  N_hos_beds  N_hot_rooms Waterbody  \
# 0   4.01        24       4.98     YES       5.480           11     River
# 1   5.06        22       9.14      NO       7.332           12      Lake
# 2   4.97        22       4.03      NO       7.394          101       NaN
# 3   5.96        21       2.94     YES       9.268           11      Lake
# 4   5.86        21       5.33      NO       8.824           11      Lake
#
#    Rainfall Bus_ter     Parks
# ...

# %%
# Find the number of missing values
df_house_price_data.isnull().sum()
# Out:
# Price            0
# Crime_rate       0
# Resid_area       0
# Air_qual         0
# Room_num         0
# Age              0
# Dist1            0
# Dist2            0
# Dist3            0
# Dist4            0
# Teachers         0
# Poor_prop        0
# Airport          0
# N_hos_beds       8
# N_hot_rooms      0
# Waterbody      155
# Rainfall         0
# Bus_ter          0
# Parks            0
# dtype: int64

# %%
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Price        506 non-null    float64
#  1   Crime_rate   506 non-null    float64
#  2   Resid_area   506 non-null    float64
#  3   Air_qual     506 non-null    float64
#  4   Room_num     506 non-null    object
#  5   Age          506 non-null    int32
#  6   Dist1        506 non-null    float64
#  7   Dist2        506 non-null    float64
#  8   Dist3        506 non-null    float64
#  9   Dist4        506 non-null    float64
#  10  Teachers     506 non-null    int32
#  11  Poor_prop    506 non-null    float64
#  12  Airport      506 non-null    object
#  13  N_hos_beds   498 non-null    float64
#  14  N_hot_rooms  506 non-null    int32
#  15  Waterbody    351 non-null    object
#  16  Rainfall     506 non-null    int64
#  17  Bus_ter      506 non-null    object
# ...

# %%
# laws
# When we have less than 10% data missing, remove the observcation
# When we have missing % value 30 to 70 % missing value than we need to inpute the missing values
# When we have more than 80% data is missing, remove the attributes

# %%
round(df_house_price_data.isnull().sum()/len(df_house_price_data)*100,2)
# Out:
# Price           0.00
# Crime_rate      0.00
# Resid_area      0.00
# Air_qual        0.00
# Room_num        0.00
# Age             0.00
# Dist1           0.00
# Dist2           0.00
# Dist3           0.00
# Dist4           0.00
# Teachers        0.00
# Poor_prop       0.00
# Airport         0.00
# N_hos_beds      1.58
# N_hot_rooms     0.00
# Waterbody      30.63
# Rainfall        0.00
# Bus_ter         0.00
# Parks           0.00
# dtype: float64

# %%
# inpute the missing values present in waterbody
# find the mode of column
df_house_price_data.Waterbody.mode()
# Out:
# 0    River
# Name: Waterbody, dtype: object

# %%
# replace the null value present in waterbody with river
df_house_price_data.Waterbody.fillna('River',inplace=True)

# %%
df_house_price_data.isnull().sum()
# Out:
# Price          0
# Crime_rate     0
# Resid_area     0
# Air_qual       0
# Room_num       0
# Age            0
# Dist1          0
# Dist2          0
# Dist3          0
# Dist4          0
# Teachers       0
# Poor_prop      0
# Airport        0
# N_hos_beds     8
# N_hot_rooms    0
# Waterbody      0
# Rainfall       0
# Bus_ter        0
# Parks          0
# dtype: int64

# %%
# We have less than 2% data is missing from N_hos_beds, let's remove the observation     
df_house_price_data.dropna(inplace=True)

# %%
df_house_price_data.isnull().sum()
# Out:
# Price          0
# Crime_rate     0
# Resid_area     0
# Air_qual       0
# Room_num       0
# Age            0
# Dist1          0
# Dist2          0
# Dist3          0
# Dist4          0
# Teachers       0
# Poor_prop      0
# Airport        0
# N_hos_beds     0
# N_hot_rooms    0
# Waterbody      0
# Rainfall       0
# Bus_ter        0
# Parks          0
# dtype: int64

# %% [markdown]
# ### Oulier detection and treatment

# %%
df_house_price_data.plot(kind='box')
plt.xticks(rotation=90)
plt.title('Oulier Detection')
plt.show()

# %%
df_num = df_house_price_data.select_dtypes(np.number)

# %%
Q1 = df_num.quantile(0.25)
Q3 = df_num.quantile(0.75) 
IQR = Q3 - Q1
df_num = df_num[(df_num >= Q1 - 1.5 * IQR) & (df_num <= Q3 + 1.5 + IQR)]

# %%
df_num = df_num.reset_index()

# %%
df_num.plot(kind= 'box')
plt.xticks(rotation=45)
plt.show()

# %%
# Concate the treated data frames with categorical data frames
df_cat = df_house_price_data.select_dtypes('object')

# %%
df_cat = df_cat.reset_index()

# %%
print(df_num.shape)
print(df_cat.shape)
# Out:
# (498, 16)
# (498, 5)

# %%
# Concate the both
df_house_price_data = pd.concat((df_num,df_cat),axis=1)
df_house_price_data.shape
# Out:
# (498, 21)

# %%
df_house_price_data.isnull().sum()
# Out:
# index           0
# Price          54
# Crime_rate     67
# Resid_area      0
# Air_qual        0
# Age             0
# Dist1           5
# Dist2           5
# Dist3           5
# Dist4           5
# Teachers       14
# Poor_prop      19
# N_hos_beds      0
# N_hot_rooms     2
# Rainfall        0
# Parks           0
# index           0
# Room_num        0
# Airport         0
# Waterbody       0
# Bus_ter         0
# dtype: int64

# %%
df_house_price_data.dropna(inplace = True)

# %%
df_house_price_data.isnull().sum()
# Out:
# index          0
# Price          0
# Crime_rate     0
# Resid_area     0
# Air_qual       0
# Age            0
# Dist1          0
# Dist2          0
# Dist3          0
# Dist4          0
# Teachers       0
# Poor_prop      0
# N_hos_beds     0
# N_hot_rooms    0
# Rainfall       0
# Parks          0
# index          0
# Room_num       0
# Airport        0
# Waterbody      0
# Bus_ter        0
# dtype: int64

# %% [markdown]
# # 3 EDA

# %%
# Univarite Analysis
# Binary Analysis
# Multivariate Analysis

# %% [markdown]
# ### Univarite Analysis

# %%
# Let's segregate he numerical columns and categorical columns
df_num = df_house_price_data.select_dtypes(include=np.number)

# %%
df_num.head() # numerical
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 3      3   33.4     0.03237       32.18     0.458   45   6.21   5.93   6.16
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0        23  0.049347
# 1   5.06      22.0       9.14       7.332         12.0        42  0.046146
# 3   5.96      21.0       2.94       9.268         11.0        45  0.047151
# 5   5.99      21.0       5.21       7.174         14.0        53  0.045910
# 6   5.20      24.0      12.43       6.958         12.0        41  0.052170
#
#    index
# 0      0
# 1      1
# 3      3
# 5      5
# ...

# %%
# categorical data frames
df_cat = df_house_price_data.select_dtypes(include=['object'])

# %%
df_cat.head()
# Out:
#   Room_num Airport Waterbody Bus_ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES
# 3        6     YES      Lake     YES
# 5        6     YES     River     YES
# 6        6     YES     River     YES

# %% [markdown]
# #### Room_num

# %%
# Find the count of each category present in that particular column
df_cat.Room_num.value_counts()
# Out:
# Room_num
# 6    224
# 5    118
# 7     15
# 4      2
# 8      1
# 3      1
# Name: count, dtype: int64

# %%
# Let's visulize the count
df_cat.Room_num.value_counts().plot(kind= 'bar',color = 'black')
plt.show()

# %% [markdown]
# **Interpretation**
#  - We have imbalance data in Room_num column
#  - 6 is category who is dominating most, it's count is 266
#  - 3 is a category having least number of observations,it's count is 2

# %% [markdown]
# #### Airport

# %%
# Find the count of Airport column
df_cat.Airport.value_counts()
# Out:
# Airport
# YES    196
# NO     165
# Name: count, dtype: int64

# %%
# plot the value count
df_cat.Airport.value_counts().plot(kind= 'bar',color = 'blue')
plt.show()

# %% [markdown]
# **Interpretation**
#  - We have balanced data in this Airport column
#  - In the data there is 273 places where airport is present and 225 places where airport is not present

# %%
df_cat.head(2)
# Out:
#   Room_num Airport Waterbody Bus_ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES

# %% [markdown]
# #### Waterbody

# %%
# find the cpunt of each category in column
df_cat.Waterbody.value_counts()
# Out:
# Waterbody
# River             240
# Lake               68
# Lake and River     53
# Name: count, dtype: int64

# %%
# visualize the value count
df_cat.Waterbody.value_counts().plot(kind= 'bar',color = 'pink')
plt.title('Count of Waterbody')
plt.ylabel('count')
plt.xlabel('Waterbodies')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - Most of the places having river as waterbody, it's count is 333
#  - There is few places where lake and river are the the waterbody
#  - This data is imbalance

# %%
df_cat.head(2)
# Out:
#   Room_num Airport Waterbody Bus_ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES

# %% [markdown]
# #### Bus_ter

# %%
# Find the count of Bus_ter column
df_cat.Bus_ter.value_counts()
# Out:
# Bus_ter
# YES    361
# Name: count, dtype: int64

# %%
# Visulize the value count
df_cat.Bus_ter.value_counts().plot(kind= 'bar',color = 'brown')
plt.xlabel('Bus Terminal')
plt.ylabel('count')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - All the places we have contain the bus terminal
#  - ACTION: Remove that column feom data

# %%
# Drop the column
df_house_price_data.drop('Bus_ter', axis=1, inplace=True)

# %%
df_house_price_data.shape
# Out:
# (361, 20)

# %%
df_house_price_data.shape[1]
# Out:
# 20

# %% [markdown]
# ## univariate analysis on numerical data

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 3      3   33.4     0.03237       32.18     0.458   45   6.21   5.93   6.16
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0        23  0.049347
# 1   5.06      22.0       9.14       7.332         12.0        42  0.046146
# 3   5.96      21.0       2.94       9.268         11.0        45  0.047151
# 5   5.99      21.0       5.21       7.174         14.0        53  0.045910
# 6   5.20      24.0      12.43       6.958         12.0        41  0.052170
#
#    index
# 0      0
# 1      1
# 3      3
# 5      5
# ...

# %% [markdown]
# #### Price

# %%
df_num.Price.plot(kind= 'kde' , color= 'red')
plt.title('kde plot on nprice')
plt.grid()
plt.show()

# %%
# Find the minimum values
df_num.Price.min()
# Out:
# 7.0

# %%
# Find the maximum value
df_num.Price.max()
# Out:
# 33.4

# %%
#Find the average value
df_num.Price.mean()
# Out:
# 21.534349030470914

# %% [markdown]
# **Interpretation**
#  - This data is slightly normal ditributed
#  - The house we have their price lies in 8 lakhs to 10 lakhs
#  - The house we have the least price 7 lakhs
#  - The house with maximum price is 33 lakhs
#  - The average house with average price is 21 lakhs

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 3      3   33.4     0.03237       32.18     0.458   45   6.21   5.93   6.16
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0        23  0.049347
# 1   5.06      22.0       9.14       7.332         12.0        42  0.046146
# 3   5.96      21.0       2.94       9.268         11.0        45  0.047151
# 5   5.99      21.0       5.21       7.174         14.0        53  0.045910
# 6   5.20      24.0      12.43       6.958         12.0        41  0.052170
#
#    index
# 0      0
# 1      1
# 3      3
# 5      5
# ...

# %% [markdown]
# #### Crime_rate

# %%
# Find the minimum values
df_num.Crime_rate.min()
# Out:
# 0.00632

# %%
# Find the maximum value
df_num.Crime_rate.max()
# Out:
# 8.64476

# %%
#Find the average value
df_num.Crime_rate.mean()
# Out:
# 1.2052241551246536

# %%
df_num.Crime_rate.plot(kind= 'kde' , color= 'red')
plt.title('kde plot on Crime_rate')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - We have normal distributed
#  - The data lies between 0.1 to 0.2
#  - We have minimum crime rate value in area is 0.00632
#  - We have maximum crime rate value in area is 8.6
#  - We have Average crime rate value in area is 1.2

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 3      3   33.4     0.03237       32.18     0.458   45   6.21   5.93   6.16
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0        23  0.049347
# 1   5.06      22.0       9.14       7.332         12.0        42  0.046146
# 3   5.96      21.0       2.94       9.268         11.0        45  0.047151
# 5   5.99      21.0       5.21       7.174         14.0        53  0.045910
# 6   5.20      24.0      12.43       6.958         12.0        41  0.052170
#
#    index
# 0      0
# 1      1
# 3      3
# 5      5
# ...

# %% [markdown]
# #### Resid_area

# %%
# Find the minimum value
df_num.Resid_area.min()
# Out:
# 30.74

# %%
#Find the maximum value
df_num.Resid_area.max()
# Out:
# 57.74

# %%
# Find the Average value
df_num.Resid_area.mean()
# Out:
# 40.651440443213296

# %%
df_num.Resid_area.plot(kind= 'kde' , color= 'red')
plt.title('kde plot on Resid_area')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is multi distributed
#  - The data lies between 30 to 40 and for second module 47 to 55
#  - We have minimum value 30
#  - We have maximum value 57
#  - We have maximum value 40

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 3      3   33.4     0.03237       32.18     0.458   45   6.21   5.93   6.16
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0        23  0.049347
# 1   5.06      22.0       9.14       7.332         12.0        42  0.046146
# 3   5.96      21.0       2.94       9.268         11.0        45  0.047151
# 5   5.99      21.0       5.21       7.174         14.0        53  0.045910
# 6   5.20      24.0      12.43       6.958         12.0        41  0.052170
#
#    index
# 0      0
# 1      1
# 3      3
# 5      5
# ...

# %%
# Find the minimum value
df_num.Air_qual.min()
# Out:
# 0.385

# %%
#Find the maximum value
df_num.Air_qual.max()
# Out:
# 0.871

# %%
#Find the Average value 
df_num.Air_qual.mean()
# Out:
# 0.537905540166205

# %%
df_num.Air_qual.plot(kind='kde', color='black')
plt.title('kde plot on Air_qual')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is not normally distributed
#  - The data lies between 0.3 to 0.9
#  - We have minimum value 0.385
#  - We have maximum value 0.871
#  - We have maximum value 0.5

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 3      3   33.4     0.03237       32.18     0.458   45   6.21   5.93   6.16
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0        23  0.049347
# 1   5.06      22.0       9.14       7.332         12.0        42  0.046146
# 3   5.96      21.0       2.94       9.268         11.0        45  0.047151
# 5   5.99      21.0       5.21       7.174         14.0        53  0.045910
# 6   5.20      24.0      12.43       6.958         12.0        41  0.052170
#
#    index
# 0      0
# 1      1
# 3      3
# 5      5
# ...

# %% [markdown]
# #### Age

# %%
# Find the minimum value
df_num.Age.min()
# Out:
# 2

# %%
#Find the maximum value
df_num.Age.max()
# Out:
# 100

# %%
#Find the Average value 
df_num.Age.mean()
# Out:
# 64.66759002770083

# %%
df_num.Age.plot(kind='kde', color='black')
plt.title('kde plot on Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is not normally distributed
#  - The data lies between 0 to 125
#  - We have minimum value 2
#  - We have maximum value 100
#  - We have maximum value 64

# %% [markdown]
# #### Dist1

# %%
# Find the minimum value
df_num.Dist1.min()
# Out:
# 1.34

# %%
#Find the maximum value
df_num.Dist1.max()
# Out:
# 9.44

# %%
#Find the Average value 
df_num.Dist1.mean()
# Out:
# 4.275096952908587

# %%
df_num.Dist1.plot(kind='kde', color='black')
plt.title('kde plot on Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is slightly normally distributed
#  - The data lies between 0 to 11
#  - We have minimum value 1.34
#  - We have maximum value 9.44
#  - We have maximum value 4.27

# %% [markdown]
# #### Dist2

# %%
# Find the minimum value
df_num.Dist2.min()
# Out:
# 1.04

# %%
#Find the maximum value
df_num.Dist2.max()
# Out:
# 9.11

# %%
#Find the Average value 
df_num.Dist2.mean()
# Out:
# 3.932216066481995

# %%
df_num.Dist2.plot(kind='kde', color='black')
plt.title('kde plot on Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is slightly normally distributed
#  - The value llies between 0 to 11
#  - We have minimum value 1.04
#  - We have maximum value 9.11
#  - We have maximum value 3.93

# %% [markdown]
# #### Dist3

# %%
# Find the minimum value
df_num.Dist3.min()
# Out:
# 1.57

# %%
#Find the maximum value
df_num.Dist3.max()
# Out:
# 9.48

# %%
#Find the Average value 
df_num.Dist3.mean()
# Out:
# 4.268199445983379

# %%
df_num.Dist3.plot(kind='kde', color='black')
plt.title('kde plot on Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is slightly normally distributed
#  - The value lies between 0 to 11
#  - We have minimum value 1.57
#  - We have maximum value 9.48
#  - We have maximum value 4.26

# %% [markdown]
# #### Dist4

# %%
# Find the minimum value
df_num.Dist4.min()
# Out:
# 1.01

# %%
#Find the maximum value
df_num.Dist4.max()
# Out:
# 9.16

# %%
#Find the Average value 
df_num.Dist4.mean()
# Out:
# 3.9178947368421055

# %%
df_num.Dist4.plot(kind='kde', color='black')
plt.title('kde plot on Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is slightly normally distributed
#  - The value llies between 0 to 10
#  - We have minimum value 0.73
#  - We have maximum value 11.94
#  - We have maximum value 3.63

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 3      3   33.4     0.03237       32.18     0.458   45   6.21   5.93   6.16
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0        23  0.049347
# 1   5.06      22.0       9.14       7.332         12.0        42  0.046146
# 3   5.96      21.0       2.94       9.268         11.0        45  0.047151
# 5   5.99      21.0       5.21       7.174         14.0        53  0.045910
# 6   5.20      24.0      12.43       6.958         12.0        41  0.052170
#
#    index
# 0      0
# 1      1
# 3      3
# 5      5
# ...

# %% [markdown]
# #### Teachers

# %%
# Find the minimum value
df_num.Teachers.min()
# Out:
# 18.0

# %%
#Find the maximum value
df_num.Teachers.max()
# Out:
# 25.0

# %%
#Find the Average value 
df_num.Teachers.mean()
# Out:
# 20.975069252077564

# %%
df_num.Teachers.plot(kind='kde', color='black')
plt.title('kde plot on Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is not normally distributed
#  - The value llies between 16 to 28
#  - We have minimum value 18
#  - We have maximum value 27
#  - We have maximum value 21.03

# %% [markdown]
# #### Poor_prop

# %%
# Find the minimum value
df_num.Poor_prop.min()
# Out:
# 2.94

# %%
#Find the maximum value
df_num.Poor_prop.max()
# Out:
# 28.32

# %%
#Find the Average value 
df_num.Poor_prop.mean()
# Out:
# 11.740803324099724

# %%
df_num.Poor_prop.plot(kind='kde', color='black')
plt.title('kde plot on Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is slightly normally distributed
#  - The value llies between 0 to 40
#  - We have minimum value 1.73
#  - We have maximum value 37.97
#  - We have maximum value 12.5

# %%
df_num.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 3      3   33.4     0.03237       32.18     0.458   45   6.21   5.93   6.16
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0        23  0.049347
# 1   5.06      22.0       9.14       7.332         12.0        42  0.046146
# 3   5.96      21.0       2.94       9.268         11.0        45  0.047151
# 5   5.99      21.0       5.21       7.174         14.0        53  0.045910
# 6   5.20      24.0      12.43       6.958         12.0        41  0.052170
#
#    index
# 0      0
# 1      1
# 3      3
# 5      5
# ...

# %% [markdown]
# #### N_hos_beds

# %%
# Find the minimum value
df_num.N_hos_beds.min()
# Out:
# 5.268

# %%
#Find the maximum value
df_num.N_hos_beds.max()
# Out:
# 10.668

# %%
#Find the Average value 
df_num.N_hos_beds.mean()
# Out:
# 7.8991080332409975

# %%
df_num.N_hos_beds.plot(kind='kde', color='black')
plt.title('kde plot on Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is slightly normally distributed
#  - The value llies between 4 to 12
#  - We have minimum value 5.2
#  - We have maximum value 10.8
#  - We have maximum value 7.8

# %% [markdown]
# #### N_hot_rooms

# %%
# Find the minimum value
df_num.N_hot_rooms.min()
# Out:
# 10.0

# %%
#Find the maximum value
df_num.N_hot_rooms.max()
# Out:
# 15.0

# %%
#Find the Average value 
df_num.N_hot_rooms.mean()
# Out:
# 12.487534626038782

# %%
df_num.N_hot_rooms.plot(kind='kde', color='black')
plt.title('kde plot on Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is normally distributed
#  - The value llies between 1 to 15
#  - We have minimum value 10
#  - We have maximum value 101
#  - We have maximum value 12.8

# %% [markdown]
# #### Rainfall

# %%
# Find the minimum value
df_num.Rainfall.min()
# Out:
# 3

# %%
#Find the maximum value
df_num.Rainfall.max()
# Out:
# 60

# %%
#Find the Average value 
df_num.Rainfall.mean()
# Out:
# 38.67036011080332

# %%
df_num.Rainfall.plot(kind='kde', color='black')
plt.title('kde plot on Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is slightly normally distributed
#  - The value lies between 20 to 70
#  - We have minimum value 3
#  - We have maximum value 60
#  - We have maximum value 39.3

# %% [markdown]
# #### Parks

# %%
# Find the minimum value
df_num.Parks.min()
# Out:
# 0.033291762

# %%
#Find the maximum value
df_num.Parks.max()
# Out:
# 0.086711473

# %%
#Find the Average value 
df_num.Parks.mean()
# Out:
# 0.05301571253462604

# %%
df_num.Parks.plot(kind='kde', color='black')
plt.title('kde plot on Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is normally distributed
#  - The data lies between 0.02 to 0.09
#  - We have minimum value 0.03
#  - We have maximum value 0.08
#  - We have maximum value 0.05

# %% [markdown]
# ### Bivariate Analysis

# %%
# step 1 : Do the bivariate analysis for numerical variables
# Find the correlation
df_num.corr()
# Out:
#                 index     Price  Crime_rate  Resid_area  Air_qual       Age  \
# index        1.000000 -0.103532    0.521832    0.297811  0.285660  0.066075
# Price       -0.103532  1.000000   -0.426169   -0.508393 -0.508891 -0.538817
# Crime_rate   0.521832 -0.426169    1.000000    0.556323  0.632427  0.418043
# Resid_area   0.297811 -0.508393    0.556323    1.000000  0.748200  0.593882
# Air_qual     0.285660 -0.508891    0.632427    0.748200  1.000000  0.679141
# Age          0.066075 -0.538817    0.418043    0.593882  0.679141  1.000000
# Dist1       -0.196222  0.360590   -0.451850   -0.702243 -0.742872 -0.702479
# Dist2       -0.200925  0.358929   -0.450115   -0.705092 -0.744043 -0.701422
# Dist3       -0.204008  0.358356   -0.455486   -0.706155 -0.743477 -0.703094
# Dist4       -0.186907  0.360571   -0.440949   -0.704923 -0.739639 -0.706184
# Teachers    -0.255987  0.368330   -0.320451   -0.284554 -0.136741 -0.245808
# ...

# %%
# Draw the Heat Map for correlation
sns.heatmap(df_num.corr(),annot=True)
sns.set(rc={"figure.figsize" : (22,22)})

# %%
# Price- Parks
# Resid_area - Parks
# Air_qual - Parks
# Poor_prop - parks
# Price - Poor_prop
# Age - Poor_prop
# Air_qual - Dist4
#

# %% [markdown]
# #### Price- Parks

# %%
sns.scatterplot(x='Price', y='Parks', data = df_num)
plt.title("correlation between parks and price", fontsize=20)
plt.xlabel('parks')
plt.ylabel('prices')
plt.show()

# %% [markdown]
# **Interpretation**
#  - There is slightly negative correlaton
#  - We can say that if the price of the house is high parks are lesser

# %% [markdown]
# #### Resid_area - Parks

# %%
sns.scatterplot(x='Resid_area',y='Parks', data= df_num)
plt.title("correlation between Resid_area - Parks  ", fontsize=20)
plt.xlabel('Resid_area')
plt.ylabel('Parks')
plt.show()

# %% [markdown]
# **Interpretation**
#  - There is positive corelaton
#  - We can say that if the value of Resid_area is high than parks are lesser

# %% [markdown]
# #### Air_qual - Parks

# %%
sns.scatterplot(x='Air_qual',y='Parks', data= df_num)
plt.title("correlation between Air_qual - Parks  ", fontsize=20)
plt.xlabel('Air_qual')
plt.ylabel('Parks')
plt.show()

# %% [markdown]
# **Interpretation**
#  - There is positive corelaton
#  - It's a slightly linear correlation

# %% [markdown]
# #### Poor_prop - parks

# %%
sns.scatterplot(x='Poor_prop',y='Parks', data= df_num)
plt.title("correlation between Poor_prop - Parks  ", fontsize=20)
plt.xlabel('Poor_prop')
plt.ylabel('Parks')
plt.show()

# %% [markdown]
# **Interpretation**
#  - There is positive corelaton
#  - ita a heteroscedasticity graph

# %% [markdown]
# #### Price - Poor_prop

# %%
sns.scatterplot(x='Price',y='Poor_prop', data= df_num)
plt.title("correlation between Price - Poor_prop  ", fontsize=20)
plt.xlabel('Price')
plt.ylabel('Poor_prop')
plt.show()

# %% [markdown]
# **Interpretation**
#  - There is positive correlation
#  - ita a heteroscedasticity graph

# %% [markdown]
# #### Age - Poor_prop

# %%
sns.scatterplot(x='Age',y='Poor_prop', data= df_num)
plt.title("correlation between Age - Poor_prop  ", fontsize=20)
plt.xlabel('Age')
plt.ylabel('Poor_prop')
plt.show()

# %% [markdown]
# **Interpretation**
#  - There is positive correlation
#  - ita a heteroscedasticity graph

# %% [markdown]
# #### Dist4 - Air_qual

# %%
sns.scatterplot(x='Air_qual',y='Dist4', data= df_num)
plt.title("correlation between Air_qual - Dist4  ", fontsize=20)
plt.xlabel('Air_qual')
plt.ylabel('Dist4')
plt.show()

# %% [markdown]
# **Interpretation**
#  - There is positive correlation
#  - ita a heteroscedasticity graph

# %%
# Park
# Price 
# Air_qual
# Poor_prop

# %%
x= 'Room_num'
y= 'Parks'
plt.bar(x,y,data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.show()

# %%
sns.barplot(x='Room_num', y='Parks',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Room_num')
plt.ylabel('Parks')
plt.show()

# %% [markdown]
# **Interpretation**
#  - Average number of parks are higher then number of rooms are 4
#  - Average number of parks are lesser then number of rooms are 7

# %%
df_cat.head()
# Out:
#   Room_num Airport Waterbody Bus_ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES
# 3        6     YES      Lake     YES
# 5        6     YES     River     YES
# 6        6     YES     River     YES

# %%
# Airport
sns.barplot(x='Airport', y='Parks',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Airport')
plt.ylabel('Parks')
plt.show()

# %% [markdown]
# **Interpretation**
#  - Nothing special

# %%
# Waterbody
sns.barplot(x='Waterbody', y='Parks',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Waterbody')
plt.ylabel('Parks')
plt.show()

# %% [markdown]
# **Interpretation**
#  - Nothing special

# %% [markdown]
# ### Price

# %%
df_cat.head()
# Out:
#   Room_num Airport Waterbody Bus_ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES
# 3        6     YES      Lake     YES
# 5        6     YES     River     YES
# 6        6     YES     River     YES

# %%
# Room_num
sns.barplot(x='Room_num', y='Price',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Room_num')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# **Interpretation**
#  - When the number of room are 7 than the price is high
#  - When the number of room are 4 than the price is less

# %%
# Airport
sns.barplot(x='Airport', y='Price',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Airport')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# **Interpretation**
#  - Nothing special

# %%
# Waterbody
sns.barplot(x='Waterbody', y='Price',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Waterbody')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# **Interpretation**
#  - Nothing special

# %%
df_cat.head()
# Out:
#   Room_num Airport Waterbody Bus_ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES
# 3        6     YES      Lake     YES
# 5        6     YES     River     YES
# 6        6     YES     River     YES

# %% [markdown]
# ### Air_qual

# %%
# Room_num
sns.barplot(x='Room_num', y='Air_qual',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Room_num')
plt.ylabel('Air_qual')
plt.show()

# %% [markdown]
# **Interpertation**
# - when we have best air quality in the area that time average room number is 8 in the house
# - when we have bad air quality in the area that time average room number is 4 in the house

# %%
# Airport
sns.barplot(x='Airport', y='Air_qual',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Airport')
plt.ylabel('Air_qual')
plt.show()

# %% [markdown]
# **Interpertation**
#  - Nothing special

# %%
# Waterbody
sns.barplot(x='Waterbody', y='Air_qual',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Waterbody')
plt.ylabel('Air_qual')
plt.show()

# %% [markdown]
# **Interpertation**
#  - Nothing special

# %% [markdown]
# ### Poor_prop

# %%
df_cat.head()
# Out:
#   Room_num Airport Waterbody Bus_ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES
# 3        6     YES      Lake     YES
# 5        6     YES     River     YES
# 6        6     YES     River     YES

# %%
#Room_num

sns.barplot(x='Room_num', y='Poor_prop',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Room_num')
plt.ylabel('Poor_prop')
plt.show()

# %% [markdown]
# **Interpretation**
#  - when room numbers are 5 poor protional is high
#  - when room numbers are less poor propotional rate is low

# %%
#Airport
sns.barplot(x='Airport', y='Poor_prop',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Airport')
plt.ylabel('Poor_prop')
plt.show()

# %% [markdown]
# **Interpretation**
#  - Nothing special

# %%
# Waterbody
sns.barplot(x='Waterbody', y='Poor_prop',data = df_house_price_data)
sns.set(rc={"figure.figsize":(5,5)})
plt.xlabel('Waterbody')
plt.ylabel('Poor_prop')
plt.show()

# %% [markdown]
# **Interpretation**
#  - Nothing special

# %% [markdown]
# # Multivariate Analysis

# %%
# Add hut
# Cross tab
# Pivot table

# %%
# Room_num - Parks
# Room_num - Poor_prop
# Room_num - Air_qual
# Airport - Parks
# Airport - Air_qual
# Airport - Poor_prop
# Waterbody - Parks
# Waterbody - Air_qual
# Waterbody - Poor_prop

# %%
# Pairs
# col1 : Price col2: Parks Col3 : Room_num
# col1 : Price col2: Air_qual Col3 : Room_num
# col1 : Price col2: Poor_prop Col3 : Room_num

# col1 : Price col2: Parks Col3 : Airport
# col1 : Price col2: Air_qual Col3 : Airport
# col1 : Price col2: Poor_prop Col3 : Airport

# col1 : Price col2: Parks Col3 : Waterbody
# col1 : Price col2: Air_qual Col3 : Waterbody
# col1 : Price col2: Poor_prop Col3 : Waterbody

# Note : my column 3 should be hue parameter

# %% [markdown]
# ##### col1 : Price col2: Parks Col3 : Room_num

# %%
df_house_price_data.columns
# Out:
# Index(['index', 'Price', 'Crime_rate', 'Resid_area', 'Air_qual', 'Age',
#        'Dist1', 'Dist2', 'Dist3', 'Dist4', 'Teachers', 'Poor_prop',
#        'N_hos_beds', 'N_hot_rooms', 'Rainfall', 'Parks', 'index', 'Room_num',
#        'Airport', 'Waterbody'],
#       dtype='object')

# %%
# Scatterplot
sns.scatterplot(x='Price',y='Parks', hue= 'Room_num', data=df_house_price_data)
plt.show()

# %% [markdown]
# **Interpretation**
#  - When no. of Parks is high (0.08) that time the price is low (13 lakhs) that time The average no. of Room_num is 3
#  - When no. of Parks is low (0.04) that time the Price of the house is high(36 lakhs) i that scenario we have average no. of Rooms is 8

# %% [markdown]
# #### col1 : Price col2: Air_qual Col3 : Room_num

# %%
sns.scatterplot(x='Price', y='Air_qual' , hue='Room_num', data=df_house_price_data)
plt.show()

# %% [markdown]
# **Interpretation**
# - Price - when the price of house is low (13 lakhs) Air_qual is really good (0.9) Average number of Room_num is 4
# - When the price of nhouse is high (36 lakhs) Air_qual is bad (0.5) and Avarage number of Room_num is 7

# %% [markdown]
# #### col1 : Price col2: Poor_prop Col3 : Room_num

# %%
sns.scatterplot(x='Price', y='Poor_prop', hue='Room_num', data=df_house_price_data)
plt.show()

# %% [markdown]
# **Interpretation**
# - When the price of house is low (17 lakhs) Poor_prop is high (28) nd Average number of Room_num is 5
# - When the price of nhouse is high (38 lakhs) Poor_prop is low (7) and Avarage number of Room_num is 7

# %% [markdown]
# #### col1 : Price col2: Parks Col3 : Airport

# %%
sns.scatterplot(x='Price', y='Parks', hue='Airport', data=df_house_price_data)
plt.show()

# %% [markdown]
# **Interpretation**
# - When the price of house is low (16 lakhs) Parks numbers are high (0.09) and there is no Airport available
# - When the price of house is high (38 lakhs) Parks numbers are low (0.05) and there is Airport available

# %% [markdown]
# #### col1 : Price col2: Air_qual Col3 : Airport

# %%
sns.scatterplot(x='Price', y='Air_qual', hue='Airport', data=df_house_price_data)
plt.show()

# %% [markdown]
# **Interpretation**
# - When the price of house is low (17 lakhs) Air_qual is high (0.08) and there is no Airport available
# - When the price of house is high (38 lakhs) Air_qual is low (0.04) there is Airport available

# %% [markdown]
# #### col1 : Price col2: Poor_prop Col3 : Airport

# %%
sns.scatterplot(x='Price', y='Poor_prop', hue='Airport', data=df_house_price_data)
plt.show()

# %% [markdown]
# **Interpretation**
# - When the price of house is low (23 lakhs) Poor_prop is high (28) and there is no Airport available
# - When the price of house is high (38 lakhs) Poor_prop is low (3) there is Airport available

# %% [markdown]
# #### col1 : Price col2: Parks Col3 : Waterbody

# %%
sns.scatterplot(x='Price', y='Parks', hue='Waterbody', data=df_house_price_data)
plt.show()

# %% [markdown]
# **Interpretation**
# - When the price of house is low (3 lakhs) Parks numbers are high ( above0.06) and there is River available forn Watrebody source
# - When the price of house is high (38 lakhs) Parks umbers are low (0.05) there is River or Lake available for waterbody source

# %% [markdown]
# #### col1 : Price col2: Air_qual Col3 : Waterbody

# %%
sns.scatterplot(x='Price', y='Air_qual', hue='Waterbody', data=df_house_price_data)
plt.show()

# %% [markdown]
# **Interpretation**
# - When the price of house is low (3 lakhs) Air_qual is high ( above 0.6) and there is River available for Watrebody source
# - When the price of house is high (38 lakhs) Air_qual  is low (higher than 0.4) there is River or Lake available for waterbody source

# %% [markdown]
# #### # col1 : Price col2: Poor_prop Col3 : Waterbody

# %%
sns.scatterplot(x='Price', y='Poor_prop', hue='Waterbody', data=df_house_price_data)
plt.show()

# %% [markdown]
# **Interpretation**
# - When the price of house is low (3 lakhs) Poor_prop is high (24) and there is River available for Watrebody source
# - When the price of house is high (38 lakhs) Poor_prop  is low (2) there is Lake available for waterbody source

# %% [markdown]
# ### Arrangement of pivot and cross tab

# %%
# Room_num - Parks
# Room_num - Poor_prop
# Room_num - Air_qual
# Airport - Parks
# Airport - Air_qual
# Airport - Poor_prop
# Waterbody - Parks
# Waterbody - Air_qual
# Waterbody - Poor_prop

# %%
# Pairs
# col1 : Room_num col2: Airport Col3 : Price
# col1 : Room_num col2: Waterbody Col3 : Price
# col1 : Airport col2: Waterbody Col3 : Price

# %%
df_house_price_data.head()
# Out:
#    index  Price  Crime_rate  Resid_area  Air_qual  Age  Dist1  Dist2  Dist3  \
# 0      0   24.0     0.00632       32.31     0.538   65   4.35   3.81   4.18
# 1      1   21.6     0.02731       37.07     0.469   78   4.99   4.70   5.12
# 3      3   33.4     0.03237       32.18     0.458   45   6.21   5.93   6.16
# 5      5   28.7     0.02985       32.18     0.458   58   6.22   5.80   6.23
# 6      6   22.9     0.08829       37.87     0.524   66   5.87   5.47   5.70
#
#    Dist4  Teachers  Poor_prop  N_hos_beds  N_hot_rooms  Rainfall     Parks  \
# 0   4.01      24.0       4.98       5.480         11.0        23  0.049347
# 1   5.06      22.0       9.14       7.332         12.0        42  0.046146
# 3   5.96      21.0       2.94       9.268         11.0        45  0.047151
# 5   5.99      21.0       5.21       7.174         14.0        53  0.045910
# 6   5.20      24.0      12.43       6.958         12.0        41  0.052170
#
#    index Room_num Airport Waterbody
# ...

# %% [markdown]
# ### col1 : Room_num col2: Airport Col3 : Price

# %%
df_house_price_data.columns
# Out:
# Index(['index', 'Price', 'Crime_rate', 'Resid_area', 'Air_qual', 'Age',
#        'Dist1', 'Dist2', 'Dist3', 'Dist4', 'Teachers', 'Poor_prop',
#        'N_hos_beds', 'N_hot_rooms', 'Rainfall', 'Parks', 'index', 'Room_num',
#        'Airport', 'Waterbody'],
#       dtype='object')

# %% [markdown]
# ### Cross Tab

# %%
pd.crosstab(df_house_price_data.Room_num,
           df_house_price_data.Airport,
           values=df_house_price_data.Price,
           aggfunc='mean')
# Out:
# Airport          NO        YES
# Room_num
# 3               NaN  27.500000
# 4         19.000000        NaN
# 5         17.670000  19.425862
# 6         22.466667  22.603906
# 7         29.916667  30.000000
# 8         21.900000        NaN

# %% [markdown]
# ###  col1 : Room_num col2: Waterbody Col3 : Price

# %%
pd.crosstab(df_house_price_data.Room_num,
           df_house_price_data.Waterbody,
           values=df_house_price_data.Price,
           aggfunc='mean')
# Out:
# Waterbody    Lake  Lake and River      River
# Room_num
# 3             NaN             NaN  27.500000
# 4          21.900             NaN  16.100000
# 5          18.360       18.794118  18.531579
# 6          22.550       22.320588  22.594079
# 7          30.025       32.600000  29.355556
# 8             NaN             NaN  21.900000

# %% [markdown]
# ### col1 : Airport col2: Waterbody Col3 : Price

# %%
pd.crosstab(df_house_price_data.Airport,
           df_house_price_data.Waterbody,
           values=df_house_price_data.Price,
           aggfunc='mean')
# Out:
# Waterbody       Lake  Lake and River      River
# Airport
# NO         20.196296       20.233333  21.334259
# YES        22.258537       23.330435  21.729545

# %% [markdown]
#  ### col1 : Airport col2: Waterbody Col3 : Price

# %%
pd.pivot_table(data=df_house_price_data , index='Airport',
           columns='Waterbody',
           values='Price',
               
           aggfunc='mean')
# Out:
# Waterbody       Lake  Lake and River      River
# Airport
# NO         20.196296       20.233333  21.334259
# YES        22.258537       23.330435  21.729545
